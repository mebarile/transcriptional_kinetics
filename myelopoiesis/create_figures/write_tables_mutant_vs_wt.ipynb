# %% [markdown]
# # Write tables KO vs WT

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt

# %%
from matplotlib.colors import LinearSegmentedColormap
color_map = LinearSegmentedColormap.from_list('ss2_to_10x', ['red', 'lightgrey', 'blue'])

# %%
data = pd.read_csv('../results/all_parameters.txt',header=None)
features = pd.read_csv('../data_input/list_genes.csv',header=0,index_col=0)
time = pd.read_csv('../results/time_dpt_w_m.txt',header=None)

# %%
vec = data.columns
lt = list(time)

# %%
list_temp = []

# %%
for i in range(len(lt)):
    list_temp.append('alpha'+ str(lt[i]))
    
for i in range(len(lt)):
    list_temp.append('beta'+ str(lt[i]))
    
for i in range(len(lt)):
    list_temp.append('gamma'+ str(lt[i]))

# %%
data.index = data[0]
data.index = features['Gene']
data = data.T
data.index = list_temp

# %%
vec = np.array([0 for i in range(data.shape[0])],dtype = 'float')
vec2 = np.array([0 for i in range(data.shape[0])],dtype = 'float')

vec[:len(lt)] = list(time.loc[0]*1.88)
vec[len(lt):len(lt)*2] = list(time.loc[0]*1.88)
vec[len(lt)*2:len(lt)*3] = list(time.loc[0]*1.88)

vec2[:len(lt)] = list(time.loc[1])
vec2[len(lt):len(lt)*2] = list(time.loc[1])
vec2[len(lt)*2:len(lt)*3] = list(time.loc[1])


data['dpt'] = vec
data['cell_index'] = vec2

data = data.T

data.to_csv('../results/table_genes.csv')

# %% [markdown]
# # Plot on umap

# %%
data = pd.read_csv('../results/table_genes.csv',index_col=0)

# %%
adata = sc.read('../data_input/adata_myelopoiesis.h5ad')

# %%
adata = adata[(adata.obs_names.str.endswith('-2')) | (adata.obs_names.str.endswith('-5')),:].copy()

# %%
data_tr = data.iloc[:,:3773].copy()
data_tr = data_tr.T

data_sp = data.iloc[:,3773:3773*2].copy()
data_sp = data_sp.T

data_de = data.iloc[:3773*2:3773*3].copy()
data_de = data_de.T

# %%
adata = adata[adata.obs.sort_values(by='dpt_pseudotime').index].copy()

# %%
adata.obs['dif_tr_rate_wdr12'] = list(-data_tr['Wdr12'])
adata.obs['dif_sp_rate_cd74'] = list(-data_sp['Cd74'])

# %%
sc.pl.umap(adata,color = ['dif_tr_rate_wdr12','dif_sp_rate_cd74'],s = 100,color_map=color_map,save = '_rates_myelopoiesis.png')#
# Out:
# WARNING: saving figure to file figures/umap_rates_myelopoiesis.png

# %%
sc.pl.umap(adata,ncols=2,color = ['dpt_pseudotime','wt_ko'],s = 50,color_map=color_map,save = '_info_myelopoiesis.png')
# Out:
# WARNING: saving figure to file figures/umap_info_myelopoiesis.png
